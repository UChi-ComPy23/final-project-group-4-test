# %%
import sys
import os

sys.path.append(os.path.abspath(".."))
from src.Metroplis2 import *
import numpy as np

# %%
N = 40
beta_range = np.linspace(0.37, 0.47, 50)
n_samples = 1000

results = simulate_ising(
    N=N,
    beta_range=beta_range,
    n_samples=n_samples,
    n_therm=1000,
    init_mode="cold",   # you can try "hot"
    n_blocks=20,
)

critical_beta = estimate_critical_temperature(results, beta_range)
plot_results_error(results, N)
# Out:
# Metropolis Simulating: 100%|██████████| 50/50 [15:30<00:00, 18.62s/it]
# Estimated Critical Beta (1/T): 0.406734693877551
# Estimated Critical Temperature Tc: 2.4586051179126946

# %%
N = 60
beta_range = np.linspace(0.37, 0.47, 50)
n_samples = 1000

results = simulate_ising(
    N=N,
    beta_range=beta_range,
    n_samples=n_samples,
    n_therm=1000,
    init_mode="cold",   # you can try "hot"
    n_blocks=20,
)

critical_beta = estimate_critical_temperature(results, beta_range)
plot_results_error(results, N)
# Out:
# Metropolis Simulating: 100%|██████████| 50/50 [34:53<00:00, 41.88s/it]
# Estimated Critical Beta (1/T): 0.4353061224489796
# Estimated Critical Temperature Tc: 2.297233942803563
